# %% [markdown]
# # Topic Modeling on Twitter Dataset using LDA

# %% [markdown]
# #### Importing libraries

# %% [markdown]
# ##### Uncomment this section while running the notebook for the first time

# %%
# ! pip install pandas
# ! pip install spacy
# ! pip install gensim
# ! pip install pickle
# ! pip install pyLDAvis
# ! python -m spacy download en_core_web_lg

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import spacy
from spacy.lang.en import English
import pyLDAvis
from pyLDAvis import gensim_models
from gensim import corpora
import pickle
import gensim

import warnings
warnings.filterwarnings('ignore')
# Out:
# /Users/nishitchaudhry/opt/anaconda3/envs/ub_social/lib/python3.8/site-packages/gensim/matutils.py:22: DeprecationWarning: Please use `triu` from the `scipy.linalg` namespace, the `scipy.linalg.special_matrices` namespace is deprecated.
#   from scipy.linalg.special_matrices import triu

# %%
nlp = spacy.load("en_core_web_lg")

# %% [markdown]
# #### Reading twitter dataset (combined_excel_files)

# %%
df_1 = pd.read_csv('../data/excel_files/combined_twitter_df.csv', index_col=0)
df_1.head()
# Out:
#                                                Tweet  \
# 0  @TheBuffaloNews Great to see the osteointegrat...
# 1  After an @AANMember study documented the pay g...
# 2  Join #UBGSE for Black History Nerds Saturday S...
# 3  Michael Rembis is the director of the Center f...
# 4  Thank you, @NeurologyToday, for giving me the ...
#
#                                              Hashtag
# 0                                                NaN
# 1                                           ubuffalo
# 2                   ubgse blackhistorymonth ubuffalo
# 3                                                NaN
# 4  paygaps genderinequity neurology ubuffalo wome...

# %%
hashtags_1 = []

for data in df_1['Hashtag'].dropna():
    for word in data.split(' '):
        hashtags_1.append(word.strip("'#@*&,:;/").lower())

# %% [markdown]
# #### Reading twitter data (combined_new_files)

# %%
df_2 = pd.read_csv('../data/combined_files/combined_new_files.csv', index_col=0)
df_2.rename(columns={'Tweets':'Tweet'}, inplace=True)
df_2.head()
# Out:
#                                                Tweet
# 0  Nice  endorsement  of  #BuildBackBetter    and...
# 1   She  will  be  missed.  https://t.co/U2eVs49mHg'
# 2  #UBBulls    #GoBulls  #SelfEfficacy  05/24/202...
# 3  Lies  are  shame.  The  one  you  retweeted  p...
# 4  I  believe  that  he  is  the  third  @ubalumn...

# %%
hashtags_2 = []
for data in df_2['Tweet']:
    for word in data.split(' '):
        if word.startswith('#'):
            hashtags_2.append(word.strip("'#@*&,:;/").lower())

# %% [markdown]
# #### Making hashtags list

# %%
hashtags=hashtags_1+hashtags_2

unique_hashtags = set(hashtags)

# %% [markdown]
# #### Datascraping Hashtags to use as stopwords

# %%
stopwords = ['ubuffalo', 'ubtrueblue', 'ubhornsup', 'ubalumni', 'ubgse', 'ubbulls', 'ubmgt']

# %% [markdown]
# #### Reading dataset with all tweets

# %%
df = pd.read_csv('../data/combined_files/all_tweets.csv', index_col=0)
df.head()
# Out:
#                                                Tweet
# 0  @TheBuffaloNews Great to see the osteointegrat...
# 1  After an @AANMember study documented the pay g...
# 2  Join #UBGSE for Black History Nerds Saturday S...
# 3  Michael Rembis is the director of the Center f...
# 4  Thank you, @NeurologyToday, for giving me the ...

# %% [markdown]
# #### Extracting twitter account names to exclude from analysis

# %%
ats = []
for data in df['Tweet']:
    for word in data.split(' '):
        if word.startswith('@'):
            ats.append(word.strip('@').lower())

# %%
custom_stopwords = ats+stopwords
len(custom_stopwords)
# Out:
# 10198

# %% [markdown]
# #### adding custom stopwords

# %%
nlp.Defaults.stop_words |= set(custom_stopwords)
nlp.Defaults.stop_words
# Out:
# {'',
#  'another',
#  'full',
#  'since',
#  'deltasonicwash',
#  'scottwilsonbuf',
#  "ubgse'",
#  'yalemed',
#  'ballstatefb',
#  'ssn_ballstate',
#  'aera_edresearch',
#  'john_majoreason',
#  'kristjan90',
#  'nyuniversity’s',
#  'same',
#  'bsucoachneu',
#  'thartman2u',
#  'nsbe',
#  'coachbatts11',
#  'rnwora',
#  'nine',
#  'box_band_chainz',
#  'jobqualityindex',
#  'yamphoto’s',
#  'wrestlingtexas',
#  'barrosolab',
#  'ubsphhp,',
#  'ashlynoshea',
#  "profeaustin!'",
#  'djjohnson232',
#  'jonatthebar',
#  'aare_rural_ed',
#  "ub_president'",
#  'might',
#  'drabrashear',
#  "82bulls50?'",
#  'yaf',
#  'wolfblitzer,',
#  'rittigers',
#  'ed2litt,',
#  'goingdeeppod',
#  'baldwinwallace',
#  'healthleaders',
#  'wsucougarfb',
#  'dramandanick:',
#  'ufpel',
#  'mssociety',
#  'without',
#  'kimdianaconnoll,',
#  'ubbullsfans',
#  'ubchemistry',
#  'patshellyssw',
#  'sunychancellor',
#  'latterly',
#  'nehgov',
#  'mattwal17',
#  'nysdec',
#  'jarvisrgivens',
#  'although',
#  'mcsdflorida',
#  'itong_hiu',
#  'whenever',
#  'healthequitywks',
#  'ubalumni!',
#  'prevnet',
#  'neaminzeleke',
#  'ourselves',
#  'nike',
#  'bscgradschool',
#  'amyreynolds1204.',
#  'hastingscenter',
#  'wikipedia_la',
#  'n‘t',
#  'kmphfox26:',
#  'michaelbgarrett',
#  'bomani_jones',
#  'robneyer',
#  'evangantley39',
#  'front',
#  'csuwashkewicz',
#  'isaiahiaadams.',
#  'namely',
#  'dentaltown',
#  'rentprep',
#  'ctbk45!',
#  'cmsanational',
#  "jimrome'",
#  'oakleavesnews',
#  'for',
#  'emilygirsch,',
#  'nejm',
#  'amnestyusa,',
#  'lifeatpurdue,',
#  'hickenlooper',
#  'glock_94',
#  'leggardtm',
#  'gholdym.',
#  'hetrozygous',
#  'ubglobalhealth',
#  'chrisemdin,',
#  'nspe',
#  'geoinstitute',
#  'ubcheer.',
#  'ub_etgross',
#  'aacte',
#  'friggindaisies',
#  'hereafter',
#  'keybankctr',
#  'digitalc_org',
#  'six',
#  'everywhere',
#  'foxnews',
#  'nicolekuderer',
#  'herself',
#  'harvard.',
#  "scholarteaching\\'s",
#  'wrestlingbucks,',
#  'wikipedia',
#  'googledevjp',
#  'ecmcbuffalo',
#  'ubuffalo’s',
#  'snoopdogg',
#  'cornell’s',
#  "goingdeeppod's",
#  'michaelrcaputo',
#  'unckirschner',
#  'beckyburke11',
#  'saints',
#  'gocastelobranco',
#  'forty3north',
#  'nfl',
#  'lilymasonphd',
#  'though',
#  'fordgum,',
#  'ubcas,',
#  'cj_ball_is_life',
#  'themselves',
#  'pberryrn',
#  'katerog_mph',
#  'latimes',
#  'quian1of1',
#  'concorddotorg',
#  'popfoundindia',
#  'buffaloarchplan',
#  'jim_jordan',
#  'ubengineering:',
#  'eastmandental',
#  'nyruralschools',
#  'mtracmartin,',
#  'ganhri1',
#  'h2_recruiting',
#  'mike_coachd',
#  'dev1n__50',
#  'buffalobills',
#  'mistrasgroup,',
#  'sometime',
#  'washingtonpost',
#  'hannahbuehler',
#  'dramylreynolds!',
#  'ubfootball’s',
#  'blackdiasporav1',
#  'theakrowdies',
#  'demoneharris',
#  'shannonrwaite5,',
#  'brianjayjones',
#  'cbls',
#  'zach_monell',
#  'danielsonkassa1',
#  'amnesty',
#  'gcurbaned',
#  'ubsing_alumni',
#  'edl_dyouville',
#  'which',
#  'ndmaindia',
#  'coachshanemonty',
#  'routledgebooks',
#  'dramylreynolds,',
#  'buffalofood',
#  'mwsallee,',
#  "'d",
#  'umasslowell',
#  'bankteshwart',
#  'carleton_u',
#  'daemenmbb',
#  'mildredboveda…',
#  'blackbearsfb',
#  'drlagarrettking,',
#  'ethnoforumgse',
#  'kaleidahealth,',
#  'middlebury.',
#  "healthequitywks'",
#  "ub_presid'",
#  "mjkomendat'",
#  'adam_dennett',
#  'nazarethcollege',
#  'ub_xctf',
#  'jevoke',
#  'rachelmlenzi',
#  'princeton',
#  'usports_fb',
#  'queencityautodetail',
#  'iloveuguys',
#  'paulstubbsa',
#  'fifteen',
#  'much',
#  'ubssw.',
#  'spurs.',
#  'coachmolinguist',
#  'aeesprofs',
#  'ca',
#  'annie_judasz',
#  'nrookie;',
#  'once',
#  'teacherscollege',
#  'uwmsois',
#  'oldtakesexposed',
#  'ubnewssource',
#  'ubpharm,',
#  'make',
#  'ramongoings.\n\nlearn',
#  'such',
#  'espn',
#  'mac___99',
#  'aprabhumd',
#  'xfl2023!',
#  'hallmark',
#  'give',
#  'cskrzy',
#  'ahahistorians',
#  "senatorbennet'",
#  'but',
#  'rsprasad',
#  'sajid_nadeem78',
#  'thebuffalonews',
#  'huddles10251!',
#  "ubticketoffice'",
#  'gopherfootball',
#  'buffaloarchplan’s',
#  'nate_oats',
#  "'ll",
#  'ub,',
#  "styluspub'",
#  'spencer_fdn',
#  "ubalumni.'",
#  'pff',
#  'uwtacoma',
#  'heppnerd',
#  '‘ve',
#  'pa_study',
#  'wybdc',
#  'dredoiron,',
#  'nmh_shanauermd',
#  'gop',
#  'njsmyth',
#  'ischoolui',
#  'michaelkom',
#  'teresacoffey',
#  'ubengineering',
#  'irelandinny',
#  'nacme',
#  'both',
#  'is',
#  'ricozackery',
#  'will',
#  'marissakawehi!',
#  'power_engineers',
#  'put',
#  'jodieroure,',
#  'drt_1913',
#  'herein',
#  'humanitiesgc',
#  'anchorbarwings',
#  'uconn',
#  'four',
#  'chunyan_y',
#  'now',
#  'diverseissues',
#  'popbiotech',
#  'dfi_tweets',
#  'into',
#  'sju_dlis',
#  'nrookie:',
#  'forbes:',
#  'dpshapiro',
#  'silvanus_lee',
#  'forty',
#  'ubnursing,',
#  'does',
#  "ub_president\\rhttps://t.co/npefafuqae'",
#  'ndsu',
#  'free_2_luv',
#  'whereupon',
#  'navalacademy',
#  'hoganwillig',
#  'ctipporg',
#  'ujjram',
#  'iamchikitabmann',
#  'heyrachacha',
#  'ilascd',
#  'ubwomentennis',
#  'bigditchbrewing',
#  'gerald_joseph90',
#  'been',
#  'golfman716',
#  'officialupnm',
#  'coachmoore313',
#  'erinh9',
#  'jsmcdonel',
#  'amnesty,',
#  'benton_inst',
#  'citynewsto',
#  '27tbuck',
#  'ubbiology',
#  'umasslowell.',
#  'wileynews',
#  'thesamuraicoach',
#  'michelleronline',
#  'harvardhbs',
#  'ub_mcsl',
#  'cbseindia29',
#  'tandfonline',
#  'whoever',
#  'indianembassyus',
#  'ubfootball',
#  'danielpink:',
#  'highmarkstadm',
#  "nicole_mirra!'",
#  'medaillecollege',
#  'bhoward_11',
#  'ubfellowships',
#  'victoriakirg!',
#  'summaluh',
#  'billsfanmonica',
#  'tavianm1',
#  'naswva',
#  'misterteacher92',
#  'ubswimdiveteam!',
#  'patriots',
#  'karmasashannon',
#  'fmkirbyneuro',
#  'nata1950',
#  'nrookie!',
#  'ucla',
#  '1love_football',
#  'ubenglish',
#  'visa',
#  'sunycantonnews',
#  'yjs21',
#  'smfofficialy',
#  'consjames',
#  'nindsnews',
#  "news4buffalo'",
#  'greekuniversity!',
#  'onyxinsight',
#  'extinctionr',
#  'bluecollarutbt!',
#  'even',
#  'deirising',
#  'behind',
#  'equity_allies',
#  'ubgreen',
#  'jarvisrgivens.',
#  "ubwomenshoops's",
#  'slowrollbuffalo',
#  'anything',
#  'labellaassociat',
#  'cps_ss',
#  'nwsa',
#  'writesrights',
#  'risehlth',
#  'oprah',
#  'ubittic',
#  'sunhakim7!',
#  'cclri',
#  'courty_woods',
#  'ohiowbasketball…',
#  'well',
#  'wbjonline',
#  'hence',
#  'willeasthigh',
#  'may',
#  'gbassn',
#  'slipperyrocku',
#  'bluecollarutbt',
#  'iesportsradio',
#  'coachwhite_c',
#  'have',
#  'jennacallari',
#  'her',
#  'markskevin,',
#  'naturecomms:',
#  'yours',
#  'stephsfredrick',
#  'vopnews',
#  'kvsitapur',
#  'gomeepmeep',
#  'ubstem',
#  'many',
#  "dhsgov'",
#  'comp_design',
#  'clive_bates',
#  'rather',
#  'ubswimdiveteam.',
#  'publichealth',
#  'biraqtsehay',
#  'bnnbrd11,',
#  "ubgse's",
#  'ubschooloflaw.',
#  'thereupon',
#  "citycollegeny's",
#  'cosidanews',
#  'yamphoto.',
#  'jxbarros',
#  'geographyub',
#  'sdpbuffalo,',
#  'ubbullsmafia',
#  'aandlenatu',
#  "music4literacy!'",
#  'teamdkb',
#  'bowluspeck!',
#  'an',
#  'firstphdchat',
#  'nevertheless',
#  'dpsskis—the',
#  'forbes',
#  'it',
#  'ggarciatsao',
#  'jacobs_med_ub’s',
#  'hepatomd',
#  'airnewsalerts',
#  'tim_monreal’s',
#  'pozelbhs',
#  'drmonibyrne',
#  'reporterroblang',
#  'halleee713',
#  'deptvetaffairs',
#  'should',
#  'thence',
#  'ku_football',
#  'gqmagazine?',
#  '__jp26!',
#  'casaucl',
#  'coconutpoint',
#  'praveenarany.',
#  'terrinwatson,',
#  'against',
#  "natlmortgagepro's",
#  'advisormellymel',
#  'ryanrish!',
#  'nysspe',
#  'ashagaines617',
#  'mtracmartin',
#  'cfcbuffalo',
#  'ub_president?',
#  'bengals',
#  'umbc—and',
#  'ubhonors',
#  'everyone',
#  'velazquez_lab',
#  'mdsantopietro',
#  'swetalk',
#  'coach_uzzi',
#  'using',
#  'noone',
#  'gc_cuny.',
#  're',
#  'iisaacjack',
#  'five',
#  'further',
#  'msudogsrule',
#  "ubuffalo'",
#  'lyndsaynjenkins',
#  'publicaffairsub',
#  'xfl2023',
#  'buffalomarines!',
#  'npr',
#  'heather_sol_a.',
#  'urhistorydept',
#  'canisiushsfb',
#  'ravenscimaven',
#  'amazonwatch',
#  "amy_stich!'",
#  'stjude.',
#  'hogshaven',
#  'nbcsports',
#  'drlagarrettking',
#  'if',
#  'thus',
#  'yonast98',
#  'thedemocrats.',
#  'esaofnewengland',
#  'socdetermined',
#  'missourisandt',
#  'footballlearn1',
#  'uindy',
#  'part',
#  'next',
#  'masonrschreck',
#  'nyssba',
#  'chamarlatanja',
#  'beyond',
#  'muddasir_ayazmd',
#  'ubmenshoops!',
#  'ubswce',
#  'm1key_g',
#  'uesi_asce',
#  'mac_bandwagon',
#  'coachmo15',
#  'perhaps',
#  'davidaltonhl',
#  'ubartgalleries',
#  'theocsproject',
#  'thetournament:',
#  'fanduel',
#  'wmolinich',
#  'harcummbb',
#  'bullssportsmed',
#  'ctjohnsonhigh',
#  'ohiofootball',
#  'parkmobile',
#  'bataviadowns',
#  'target',
#  'coachojong',
#  'cookcottone:',
#  'atlantisbahamas',
#  'swexner',
#  'uniteushq',
#  'chargers',
#  'xqamerica',
#  'wendelcompanies',
#  'time',
#  'see',
#  'what',
#  'barstoolmiamiu',
#  'leonardnmoore',
#  'fordguminc!',
#  "clarabauler!'",
#  'myself',
#  "cgibhs'",
#  'nyasp',
#  'wnedpbs',
#  'karenzgoda',
#  'inl.\n\ncheck',
#  'together',
#  'therein',
#  'only',
#  'markpoloncarz',
#  'militellomatt',
#  "drrandio!'",
#  'd_eck_ard',
#  'cfbhome',
#  'litmanjohnson',
#  'patriotleague',
#  'ohiowbasketball\n🕰',
#  'sarahchampionmp',
#  'tolleson20',
#  'blizzard5179',
#  'neotokyonewstv',
#  'ronwhitcomb',
#  'chadsimmons_',
#  'hobby_connect',
#  'danwolken',
#  'oprfathletics',
#  'jenniferegaddis',
#  'amongst',
#  'ssn_wmu',
#  'e_sinnott32',
#  'say',
#  'intheflow_peds!',
#  'he',
#  'summaluh,',
#  'jschildkraut80',
#  'ub_bullyprevctr!',
#  'theofficetv',
#  'libankerdc',
#  'evandavis37',
#  'ubnakedguy',
#  'gsimmo1',
#  'potus',
#  'madmax_6_',
#  'universityatbuffalo',
#  'ubwomenshoops!!',
#  'amercollphyadv',
#  'gobuffalo',
#  'ubdazzlers',
#  'buffalosabres',
#  'sljournal',
#  'too',
#  'ubssw',
#  'popstarlab’s',
#  'alliedmedia',
#  'ubcas',
#  'bonadiogroup',
#  'mical_raz',
#  'elmhurstbluejay',
#  'napractice',
#  'them',
#  'eugenepuryear',
#  'sunyesf',
#  'rural_schools',
#  'while',
#  'quentcapital',
#  'regarding',
#  'newyorkgop',
#  'nyce18,',
#  'whole',
#  'fdnyphoenixsoc',
#  'heymrsbond',
#  'moreover',
#  'laurie_rubel',
#  'nyusilver',
#  'tech813coach',
#  "patshellyssw'",
#  'runningthedusk',
#  '_mayaskinnertv',
#  "amherst_gop'",
#  'nsf',
#  'k6logc',
#  'joshuamballa',
#  'something',
#  'ubmenshoops,',
#  'ctjwrestling',
#  'yourspca!',
#  'patrickkenney7',
#  "ub_bullyprevctr's",
#  'monicaramirezoh.',
#  'dkeller330',
#  'are',
#  'various',
#  'elizotope',
#  'bbbaumgartner',
#  'ubalumni:',
#  'amnesty!',
#  'vandy_62',
#  'nasw',
#  'ub_emba',
#  'hannnnahh_c',
#  'jbethjs,',
#  'ubparking.',
#  'rsrch4schls',
#  'alanzweibel,',
#  'thejcabbott',
#  'phebenkassahun',
#  'already',
#  'umbc',
#  'ryangarby',
#  "n't",
#  'cc_columbia',
#  'byjerrysullivan',
#  'cprepharlem',
#  'cuse',
#  'aronfay',
#  'then',
#  "bisonhoops'",
#  "mattlaoshi!'",
#  'could',
#  'im_back_15',
#  'jj_gazette',
#  'kimacquaviva',
#  'ed2litt',
#  'richproducts,',
#  'anna_lvovsky',
#  'suny_esports',
#  'researchosu',
#  'we',
#  'ballerschoice1',
#  'few',
#  'pat_history',
#  'jarvisgivens',
#  'ballstate',
#  'raymach70',
#  'shaathletics',
#  'must',
#  'montclairstateu',
#  'ubticketoffice',
#  'vantagepoint',
#  'bigditchbrewing!',
#  'netplusalliance',
#  'between',
#  'amnestyusa',
#  'unitedfoodbank',
#  'do',
#  'ubmenshoops!!!',
#  'oprfwrestling',
#  'bully_research',
#  'mulugettayacob',
#  'aftunion',
#  'dadsonsports',
#  'ubtrueblue!',
#  '_thedailysass',
#  'hundred',
#  'ubfootball?',
#  'almost',
#  'nicolenugentphd',
#  "wbbz'",
#  'nygov',
#  'wantedlysg',
#  'edinburghuni',
#  'crowflyllc',
#  'nowhere',
#  'orangetheory',
#  'chilis',
#  'sbraxtontech',
#  'alanzweibel',
#  'ub_history',
#  'ubgse)',
#  'pib_india',
#  'coachcoreye',
#  'brockport.',
#  'than',
#  'ervstours',
#  "phamtatorship'",
#  'ubadmissions',
#  'alone',
#  'bloomberg',
#  "robincogan'",
#  "pberryrn'",
#  'or',
#  'raecheleprlp',
#  'rutgersu.',
#  'integratedcare6',
#  'buffsbarstool',
#  "acescanada2020'",
#  'ubwomenshoops!💙🤘',
#  'toledofb',
#  'giftcity_',
#  'ghoulyussef',
#  'buffalostatecdc',
#  'yet',
#  'wmu_football.',
#  'xbhs_football',
#  'bsusportslink',
#  'cle_state',
#  'hamburghigh',
#  'leb112358',
#  'thebullylab',
#  'merrilllynch',
#  'independiplomat',
#  'prince_lab',
#  'in',
#  'jenncrosspls,',
#  'ascdconf',
#  'univ_system_md',
#  'steveaoki',
#  'nysocialstudies',
#  'binghamtonu',
#  'had',
#  'rymcpherson',
#  'melissareevessp',
#  'cgibhs',
#  'ndsuengineering',
#  'gijshuitsing,',
#  'anywhere',
#  'how',
#  'lyonsletters',
#  'ubscience',
#  'markskevin!',
#  '2pelab',
#  "nlihc'",
#  'jacobs_med_ub,',
#  'danygarciaco',
#  'ubuffalo',
#  'mdmahl',
#  'pitttweet',
#  'davidekirkland,',
#  'ubstudentmin',
#  'mohitlingual',
#  'cin_online',
#  'baldycenter',
#  'bhupro',
#  'rainnwilson',
#  'rg1gal',
#  'josepborrellf',
#  'guschoolofed',
#  'marquiswhoswho.',
#  'lakingsinsider',
#  'casaucl!',
#  'ibpaworld',
#  'wherein',
#  'serious',
#  'herantigray',
#  'carnegiecorp',
#  'northstarsfball',
#  'jeopardy',
#  'dramandanick,',
#  'dvegas24',
#  'aboutharassment',
#  'ubbulls!',
#  'stevegelbs',
#  'terrinwatson',
#  'uwbec',
#  'mdandersonnews',
#  'maraswan',
#  'sandialabs',
#  'ecdoh',
#  'ramongoings.',
#  'espnu',
#  'jgorlewski',
#  'darthdeverell,',
#  'theshathitfan',
#  'siswsu',
#  'btnewsroom',
#  'foodsmartbyzip',
#  'nothing',
#  'aljayhenderson_',
#  'bmhcaucus',
#  'angelakinsey',
#  'ubgse',
#  'strayosai',
#  'launchpad_ub',
#  'across',
#  'whether',
#  'ubschoolofmgt,',
#  'ubdentalalumni',
#  'williamsruto',
#  "ubuffalo's",
#  'first',
#  'kadofi',
#  'thegiml.',
#  'civics101pod',
#  'dr_milez',
#  'launch_ny',
#  'binghamtonsom',
#  'a',
#  'kentstwbb’s',
#  'emishaweskedar',
#  'ubjonfuller',
#  'uceajsn',
#  'missiedeedee',
#  'kaleidahealth',
#  'hillelofbuffalo',
#  'stanford',
#  'ubmenstennis',
#  'triciamatthew',
#  'ub_bullyprevctr',
#  "barstoolbigcat'",
#  'jtturnbull1',
#  'wikiwomeninred',
#  'ub_english',
#  'macsports,',
#  'gbhick08',
#  'afarwatch',
#  'davidekirkland;',
#  'gcurbaned,',
#  'stephr96',
#  'just',
#  'zoebchance.',
#  'lizzieabymd',
#  'jakezembiec',
#  'seemed',
#  'tim_monreal',
#  'with',
#  'mcspencinator,',
#  '’d',
#  'chandrpk',
#  'bulls_wcrtc',
#  'ubtrueblue?!?',
#  'stemnola',
#  'switchfinder',
#  'nsyracusecns',
#  'outkick',
#  'dyouville',
#  'theihi',
#  'debanik15',
#  'ubhornsup',
#  'bradriter',
#  'smithschool',
#  'ubwomentennis!',
#  'where',
#  'cwru',
#  'baconterr',
#  'cusefootball',
#  'becomes',
#  'throughout',
#  'thememoryfox',
#  'mhromowyk!',
#  'bottom',
#  'roswellhemonc',
#  'ubspectrum!',
#  'johnkrasinski',
#  'also',
#  'made',
#  'alexwyglinski',
#  'sarakolipinski',
#  'energy',
#  'efinegan40',
#  'nucareerservice',
#  'pwc',
#  '5pm\nlearn',
#  'at',
#  'james44starks',
#  'uupinfo',
#  'dom_insouciant',
#  'epl_ualbany',
#  'qinghua_chen,',
#  'among',
#  'jimssteakout',
#  'otherwise',
#  'frederickkowal',
#  'ubbrianwolff',
#  'uconnengineer',
#  'americanacad.',
#  'theactionnet',
#  'dezj98',
#  'jacobsmedub',
#  'fordhamgse',
#  'bray1en!',
#  'ubuntu4change',
#  'nfl,',
#  'mostly',
#  'pm_alberti\n🔹#covid19',
#  "ubcommunity'",
#  'goacta',
#  'buffaloscribe',
#  'jacksonscholars',
#  'officialnyssma',
#  'yabatuwa_lij',
#  'oakparkpatch',
#  'crisshore',
#  'ukcoachcalipari',
#  'blackwomenphds',
#  'bettermakeroom',
#  'jerrijegna',
#  'columbia,',
#  'nicholsschool',
#  "sse_csub.'",
#  'nafme',
#  'ubalumni\n#ubuffalo',
#  'csufgeology',
#  'ucea',
#  'hermela',
#  'jdubclt',
#  'emdrhap',
#  'miamiohfootball',
#  'muextension',
#  'eynews',
#  '’s',
#  'cassattdr',
#  'ubvolleyball!',
#  'miamioh_bball\n\nmiami',
#  'empty',
#  'juliebowker3',
#  'sfrcdems',
#  'ubbigblue,',
#  'afitz3105',
#  'masonschools',
#  'tuwbx',
#  'beckyburke11!',
#  'nesabsa',
#  'wionews',
#  'sometimes',
#  'sjbdhscougars',
#  'ad_thecoach',
#  'senatorreid',
#  'take',
#  'kelleyashbypaul',
#  'charitynebbe',
#  'marcy_barberic',
#  'malcolmkoonce',
#  'liverprof',
#  'joebiden',
#  'would',
#  'jiggy9_',
#  'jennafischer',
#  'ubschoolofmgt.',
#  'ualbanyedu',
#  '_dominicj10',
#  'uwmadison',
#  'afoster3__',
#  'jenncrosspls',
#  'ubgselai',
#  "ryanrish'",
#  'wolfblitzer',
#  'jxfd_',
#  'whither',
#  'ubwomentennis,',
#  'yamphoto',
#  'onlinebullying',
#  'danielpink',
#  'planetfitness',
#  'bporchestra',
#  'coachatthorpe',
#  'saefarq',
#  'ctbk45.',
#  'digitalnomadrob',
#  'before',
#  'one',
#  'bezyee',
#  'gannonu',
#  'roswellpark',
#  "elainemrussell'",
#  'go',
#  'dysclinic',
#  'tunison96',
#  'davewills34',
#  'sacnas',
#  'umbc.',
#  'nsfgrant',
#  'uba',
#  'nrookie,',
#  ...}

# %% [markdown]
# #### Cleaning data
#
# 1. Removing special characters, hyperlinks, punctuations, numbers, spaces
# 2. Removing stop words
# 6. Taking words with length greater than specified in 'min_length_word'
# 7. Taking Lemmatized version of the cleaned words
# 8. Taking Lowercase

# %%
min_length_word = 3

# %%
def data_cleaner(row):
    words = row.split(' ')
    cleaned = [word.strip('@#"*%^();><?][{}]:.&,\'') for word in words if word.startswith(('\nhttps', 'htt'))==False]
    row = ' '.join(cleaned)
    doc = nlp(row)
    result = [(token.lemma_).lower() for token in doc if token.is_stop == False and token.is_punct==False and token.is_space==False and token.is_digit==False and len(token.lemma_)>min_length_word]
    return result

# %%
df['Cleaned'] = df['Tweet'].apply(lambda x: data_cleaner(x))
df
# Out:
#                                                   Tweet  \
# 0     @TheBuffaloNews Great to see the osteointegrat...
# 1     After an @AANMember study documented the pay g...
# 2     Join #UBGSE for Black History Nerds Saturday S...
# 3     Michael Rembis is the director of the Center f...
# 4     Thank you, @NeurologyToday, for giving me the ...
# ...                                                 ...
# 6945  Join an intellectual community where leading r...
# 6946  Alex Adema, EMBA ’12, grew up as a competitive...
# 6947  Happy New Year! Cheers to a year full of renew...
# 6948  Happy New Year! Another year gone by, but anot...
# 6949  2020 is officially over. The best is really ye...
#
#                                                 Cleaned
# 0               [great, osteointegrated, program, grow]
# 1     [study, document, male, female, neurologist, t...
# 2     [join, black, history, nerds, saturday, school...
# 3     [michael, rembis, director, center, disability...
# 4     [thank, give, opportunity, speak, paygaps, gen...
# ...                                                 ...
# 6945  [join, intellectual, community, lead, research...
# 6946  [alex, adema, emba, grow, competitive, skier, ...
# 6947  [happy, year, cheer, year, renew, beginning, p...
# 6948  [happy, year, year, arrive, opportunity, seize...
# 6949  [officially, good, come, happy, year, ubmba, u...
#
# [6950 rows x 2 columns]

# %% [markdown]
# #### Building text corpus from cleaned data and saving it

# %%
dictionary = corpora.Dictionary(df['Cleaned'])
corpus = [dictionary.doc2bow(text) for text in df['Cleaned']]
pickle.dump(corpus, open('../topic_modeling/corpus.pkl', 'wb'))
dictionary.save('../topic_modeling/dictionary')

# %% [markdown]
# ### I. Using complete sentences

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------
# #### CHANGE THIS SECTION ONLY

# %%
num_topics = 5
passes = 10
random_state = 100
num_words = 5
corpus = corpus
dictionary = dictionary

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Model Building

# %%
ldamodel = gensim.models.ldamodel.LdaModel(corpus = corpus,
                                          num_topics = num_topics,
                                          id2word = dictionary,
                                          passes = passes,
                                          random_state=random_state)

ldamodel.save('../topic_modeling/model5.gensim')  #saving the model

# %% [markdown]
# #### Checking top topics

# %%
topics = ldamodel.print_topics(num_words=num_words)
for topic in topics:
    print(topic)
# Out:
# (0, '0.013*"tplf" + 0.011*"need" + 0.010*"tigray" + 0.009*"force" + 0.009*"right"')
# (1, '0.017*"buffalo" + 0.011*"admission" + 0.008*"game" + 0.008*"family" + 0.008*"deadline"')
# (2, '0.015*"year" + 0.014*"student" + 0.012*"happy" + 0.011*"share" + 0.010*"thank"')
# (3, '0.023*"student" + 0.018*"register" + 0.016*"join" + 0.012*"program" + 0.012*"learn"')
# (4, '0.023*"thank" + 0.012*"black" + 0.010*"game" + 0.010*"bulls" + 0.009*"history"')

# %% [markdown]
# #### Visualising Topics

# %%
lda_display = gensim_models.prepare(ldamodel, corpus, dictionary, sort_topics=True)
pyLDAvis.display(lda_display)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el96271401896210450567640209791"></div>
# <script type="text/javascript">
#
# var ldavis_el96271401896210450567640209791_data = {"mdsDat": {"x": [-0.13925431333660204, -0.0914903172296003, -0.1004354966799654, 0.1109890656626438, 0.22019106158352367], "y": [0.22839978890306745, -0.11333469206711261, -0.1418054425616747, -0.011962635485781997, 0.03870298121150206], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [22.65709642506514, 21.522526733223202, 20.605980085855066, 19.843272108637297, 15.371124647219295]}, "tinfo": {"Term": ["thank", "student", "tplf", "register", "admission", "pmba", "game", "tigray", "happy", "year", "share", "join", "virtual", "black", "force", "buffalo", "ubmba", "nomore", "need", "saturday", "bulls", "emba", "belovedcommunity", "family", "history", "deadline", "ubgivingday", "point", "bull", "right", "tigray", "force", "nomore", "breakthesilence", "think", "tplf", "human", "fighter", "report", "ethiopian", "crime", "tigraygenocide", "hand", "eritrean", "rampant", "westerntigray", "interview", "civilian", "startup", "beginning", "counseling", "alumna", "kindly", "develop", "issue", "priority", "tigrayan", "universityatbuffalosuny", "library", "listen", "abuse", "ethiopia", "round", "especially", "need", "right", "study", "health", "people", "discussion", "apply", "teacher", "student", "work", "help", "learn", "program", "ubgivingday", "wish", "congratulations", "inclusion", "equity", "amazing", "forward", "justice", "personal", "fast", "graduation", "ceremony", "ubms", "athlete", "entrepreneurship", "valentinesday", "colleague", "mind", "recipient", "scholar", "advice", "kwanzaa", "kind", "easter", "commencement", "global", "quickly", "thankful", "heart", "halloween", "share", "gift", "boldlybuffalo", "diversity", "happy", "ubmba", "year", "bold", "opportunity", "challenge", "grow", "explore", "grad", "love", "community", "friend", "support", "career", "great", "thank", "student", "leadership", "help", "look", "experience", "work", "alumnus", "program", "business", "today", "school", "story", "celebrate", "pmba", "virtual", "symposium", "panel", "conversation", "ready", "connect", "write", "industry", "luck", "gsegrad", "candidate", "engage", "prof", "instagram", "effort", "little", "balance", "spread", "october", "turn", "rsvp", "drive", "strategy", "ambassador", "beloved", "leading", "reshape", "doctoral", "kick", "chat", "zoom", "register", "belovedcommunity", "join", "discuss", "webinar", "student", "class", "current", "congratulation", "leader", "learn", "free", "program", "education", "march", "business", "today", "event", "place", "visit", "alumnus", "school", "graduate", "read", "online", "life", "community", "good", "team", "find", "research", "admission", "point", "final", "process", "poundtherock", "drop", "all41", "half", "facebook", "winter", "infosession", "requirement", "wing", "1,000", "akron", "donor", "truly", "competitive", "king", "building", "q&amp;a", "datum", "rebound", "gameday", "entire", "face", "inspiration", "january", "doubleheader", "classic", "vice", "family", "deadline", "stay", "miami", "season", "buffalo", "conference", "session", "application", "spring", "teaching", "minute", "annual", "play", "game", "welcome", "fall", "question", "gradschool", "lead", "team", "bull", "today", "bulls", "research", "start", "program", "school", "information", "good", "university", "work", "saturday", "true", "mother", "double", "appreciate", "golf", "prepare", "golfwithubsomaa", "nerds", "horn", "huge", "kent", "bullying", "illinois", "tournament", "number", "reach", "outing", "mothersday", "stadium", "cleveland", "blog", "room", "partner", "pharmacist", "south", "transformative", "donate", "victory", "shoot", "require", "blue", "classroom", "black", "emba", "cheer", "racial", "history", "thank", "head", "state", "coach", "bulls", "tonight", "game", "arena", "bull", "come", "bring", "alumni", "literacy", "center", "great", "week", "watch", "support", "school", "buffalo", "join", "today"], "Freq": [376.0, 642.0, 192.0, 311.0, 148.0, 152.0, 216.0, ...

# %% [markdown]
# ### II. Using Part of Speech - Nouns

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------
# #### CHANGE THIS SECTION ONLY

# %%
pos = ['NOUN', 'PROPN']
min_length_word = 3

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Extracting Part of Speech decided above from the tweets

# %%
def pos_extracter(row, part:list):
    words = row.split(' ')
    cleaned = [word.strip('@#"*%^();><?][{}]:.&,\'') for word in words if word.startswith(('\nhttps', 'http'))==False]
    row = ' '.join(cleaned)
    doc = nlp(row)
    result = [(token.lemma_).lower() for token in doc if token.is_stop == False and token.is_punct==False and token.pos_ in part and token.is_digit==False and len(token.lemma_)>min_length_word]
    return result

# %%
df['POS'] = df['Tweet'].apply(lambda x: pos_extracter(x, pos))
df.head()
# Out:
#                                                Tweet  \
# 0  @TheBuffaloNews Great to see the osteointegrat...
# 1  After an @AANMember study documented the pay g...
# 2  Join #UBGSE for Black History Nerds Saturday S...
# 3  Michael Rembis is the director of the Center f...
# 4  Thank you, @NeurologyToday, for giving me the ...
#
#                                              Cleaned  \
# 0            [great, osteointegrated, program, grow]
# 1  [study, document, male, female, neurologist, t...
# 2  [join, black, history, nerds, saturday, school...
# 3  [michael, rembis, director, center, disability...
# 4  [thank, give, opportunity, speak, paygaps, gen...
#
#                                                  POS
# 0                                          [program]
# 1  [study, neurologist, neurologist, health, scie...
# 2  [black, history, nerds, saturday, school, hill...
# 3  [michael, rembis, director, center, disability...
# 4  [opportunity, paygaps, genderinequity, neurolo...

# %% [markdown]
# #### Building and Saving POS Text Corpus

# %%
dictionary_nouns = corpora.Dictionary(df['POS'])
corpus_nouns = [dictionary_nouns.doc2bow(text) for text in df['POS']]
pickle.dump(corpus_nouns, open('../topic_modeling/corpus_nouns.pkl', 'wb'))
dictionary_nouns.save('../topic_modeling/dictionary_nouns')

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------
# #### CHANGE THIS SECTION ONLY

# %%
num_topics = 5
passes = 10
random_state = 100
num_words = 5
corpus = corpus_nouns
dictionary = dictionary_nouns

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Modeling using new POS data

# %%
ldamodel_nouns = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                          num_topics = num_topics,
                                          id2word = dictionary,
                                          passes = passes,
                                        random_state=random_state)

ldamodel_nouns.save('../topic_modeling/model5_nouns.gensim')   #saving the model

# %% [markdown]
# #### Checking top topics

# %%
topics_nouns = ldamodel_nouns.print_topics(num_words=num_words)
for topic in topics_nouns:
    print(topic)
# Out:
# (0, '0.019*"year" + 0.018*"ubmba" + 0.017*"game" + 0.017*"congratulation" + 0.016*"bulls"')
# (1, '0.018*"tigray" + 0.016*"thank" + 0.016*"buffalo" + 0.014*"nomore" + 0.014*"force"')
# (2, '0.017*"student" + 0.012*"happy" + 0.011*"deadline" + 0.010*"school" + 0.010*"program"')
# (3, '0.032*"student" + 0.029*"program" + 0.025*"school" + 0.019*"today" + 0.017*"education"')
# (4, '0.014*"diversity" + 0.013*"student" + 0.010*"point" + 0.009*"inclusion" + 0.008*"equity"')

# %% [markdown]
# #### Visualising Topics

# %%
lda_display_nouns = gensim_models.prepare(ldamodel_nouns, corpus, dictionary, sort_topics=True)
pyLDAvis.display(lda_display_nouns)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el96271401902393898402805194794"></div>
# <script type="text/javascript">
#
# var ldavis_el96271401902393898402805194794_data = {"mdsDat": {"x": [-0.12421712146153001, 0.2030865890115163, -0.19390064707387578, 0.012110143649580282, 0.10292103587430916], "y": [-0.09928182171760955, 0.12319202740792941, 0.17364067535893776, -0.18334837893458145, -0.014202502114676144], "topics": [1, 2, 3, 4, 5], "cluster": [1, 1, 1, 1, 1], "Freq": [22.549382135340213, 22.367601620945926, 19.715029600384238, 18.22394873185997, 17.14403791146965]}, "tinfo": {"Term": ["program", "ubmba", "congratulation", "tigray", "thank", "register", "bulls", "education", "game", "school", "nomore", "force", "diversity", "tplf", "leadership", "admission", "pmba", "bull", "gradschool", "belovedcommunity", "question", "buffalo", "story", "happy", "session", "campus", "application", "breakthesilence", "point", "congratulations", "ubmba", "congratulation", "bull", "congratulations", "love", "beginning", "accounting", "luck", "blog", "miami", "basketball", "october", "entrepreneur", "ohio", "tournament", "advice", "half", "sustainability", "kent", "mind", "number", "comment", "lesson", "cleveland", "start", "tesluk", "stadium", "championship", "environment", "lead", "bulls", "story", "season", "hand", "game", "post", "state", "arena", "weekend", "alumnus", "year", "board", "tonight", "team", "alumni", "buffalo", "grad", "night", "home", "opportunity", "leadership", "career", "business", "today", "happy", "student", "community", "work", "admission", "gradschool", "question", "session", "symposium", "black", "teaching", "literacy", "talk", "noon", "application", "infosession", "instagram", "experience", "classroom", "july", "racial", "ambassador", "history", "register", "nerds", "curriculum", "horn", "buffalony", "tune", "kwanzaa", "schools", "afternoon", "supply", "investment", "graduate", "professional", "pmba", "belovedcommunity", "education", "tomorrow", "future", "program", "school", "panel", "information", "student", "info", "today", "march", "event", "community", "conversation", "management", "faculty", "class", "career", "research", "thank", "nomore", "force", "tigray", "tplf", "breakthesilence", "fighter", "campus", "ethiopia", "abuse", "westerntigray", "civilian", "golf", "ceremony", "educator", "group", "tigrayan", "visit", "colleague", "outing", "library", "wing", "interview", "june", "meeting", "commencement", "bullying", "manager", "sign", "halloween", "tigraygenocide", "crime", "family", "discussion", "leadership", "friend", "buffalo", "leader", "university", "week", "class", "year", "management", "people", "career", "student", "diversity", "point", "inclusion", "equity", "congrats", "child", "competition", "startup", "system", "fund", "athlete", "click", "issue", "universityatbuffalosuny", "kindly", "entrepreneurship", "dollar", "boldlybuffalo", "hour", "internationalwomensday", "knowledge", "balance", "attention", "heart", "kind", "programming", "internship", "rebound", "commitment", "panasci", "donor", "service", "gift", "quality", "justice", "support", "dean", "business", "care", "student", "research", "work", "challenge", "today", "team", "life", "deadline", "program", "thing", "blue", "motivationalmonday", "counseling", "poundtherock", "facebook", "country", "policy", "tuesday", "western", "case", "line", "white", "journey", "letter", "easter", "rsvp", "michigan", "king", "datum", "decision", "eastern", "mothersday", "mentalhealth", "public", "worker", "residency", "charge", "dissertation", "training", "emba", "deadline", "mother", "coach", "happy", "health", "achievement", "news", "spring", "alberti", "teacher", "all41", "research", "student", "york", "scholarship", "school", "program", "today", "success", "education", "study"], "Freq": [389.0, 182.0, 169.0, 151.0, 142.0, 165.0, 167.0, 201.0, 195.0, 357.0, 122.0, 116.0, 110.0, 112.0, 194.0, 117.0, 150.0, 115.0, 113.0, 156.0, 113.0, 329.0, 119.0, 141.0, 99.0, 91.0, 101.0, 87.0, 81.0, 92.0, 181.40790373147203, 168.77717537033655, 114.3118027677288, 91.59984663485231, 62.511106 ...

# %% [markdown]
# ### III. Testing for optimal number of topics based on Coherence and Perplexity scores

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------
# #### CHANGE THIS SECTION ONLY

# %%
max_topics = 10

passes = 10
random_state = 100
num_words = 5
corpus = corpus_nouns
dictionary = dictionary_nouns

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------

# %%
# THIS SECTION IS TAKEN FROM JASMINE'S CODE

from gensim.models import CoherenceModel

result={'number_topics': [], 'coherence_scores': [], 'perplexity_scores':[]}

print('Calculating Coherence and Perplexity Scores')
print('')
for t in range(2,max_topics+1):
    print(f'Topic number: {t}')


    # Build LDA model elbow chart
    lda_model_f = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=t, 
                                           random_state=random_state,
                                           passes=passes)


    # Compute Perplexity
    perp_score = lda_model_f.log_perplexity(corpus)
    print('\nPerplexity: ', lda_model_f.log_perplexity(corpus))  # a measure of how good the model is. The lower the better.

    # Compute Coherence Score
    coherence_model_lda = CoherenceModel(model=lda_model_f, texts=df['POS'], dictionary=dictionary, coherence='c_v')
    coherence_lda = coherence_model_lda.get_coherence()

    print('\nCoherence Score: ', coherence_lda)
    print('-'*50)

    result["number_topics"].append(t)
    result["coherence_scores"].append(coherence_lda)
    result["perplexity_scores"].append(perp_score)

topics = pd.DataFrame(result)

opt=max(topics.coherence_scores)
perp=min(topics.perplexity_scores)
topicindex_c=topics.number_topics[topics.coherence_scores==opt].values[0]
topicindex_p=topics.number_topics[topics.perplexity_scores==perp].values[0]
print('')
print('')
print('*'*50)
print(f'Best Perplexity topic:{topicindex_p}')
print(f'Best Coherence topic:{topicindex_c}')
print('*'*50)
topics
# Out:
# Calculating Coherence and Perplexity Scores
#
# Topic number: 2
#
# Perplexity:  -7.9823324193482055
#
# Coherence Score:  0.35233979462066556
# --------------------------------------------------
# Topic number: 3
#
# Perplexity:  -8.023052403058067
#
# Coherence Score:  0.2898134000426386
# --------------------------------------------------
# Topic number: 4
#
# Perplexity:  -8.03105735855205
#
# Coherence Score:  0.35331365041598883
# --------------------------------------------------
# Topic number: 5
#
# Perplexity:  -8.08949084790647
#
# Coherence Score:  0.3898553571166121
# --------------------------------------------------
# Topic number: 6
#
# Perplexity:  -8.147842735358472
#
# Coherence Score:  0.35097980229008036
# --------------------------------------------------
# Topic number: 7
#
# Perplexity:  -8.189923995835622
#
# Coherence Score:  0.4232424101205131
# --------------------------------------------------
# Topic number: 8
#
# Perplexity:  -8.217163484431989
#
# Coherence Score:  0.4360399764708613
# --------------------------------------------------
# Topic number: 9
#
# Perplexity:  -8.233301197673525
#
# Coherence Score:  0.4228773537006473
# --------------------------------------------------
# Topic number: 10
#
# Perplexity:  -8.25847304231195
#
# Coherence Score:  0.39479524056713833
# --------------------------------------------------
#
#
# **************************************************
# Best Perplexity topic:10
# Best Coherence topic:8
# **************************************************
#    number_topics  coherence_scores  perplexity_scores
# 0              2          0.352340          -7.982332
# 1              3          0.289813          -8.023053
# 2              4          0.353314          -8.031056
# 3              5          0.389855          -8.089487
# 4              6          0.350980          -8.147830
# 5              7          0.423242          -8.189861
# 6              8          0.436040          -8.217179
# 7              9          0.422877          -8.233353
# 8             10          0.394795          -8.258506

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------
# #### CHANGE THIS SECTION ONLY

# %% [markdown]
# #### Choose num_topics with lowest Perplexity score and highest Coherence score

# %%
num_topics_opt = 7

# %% [markdown]
# ### --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Modeling using Optimal Topics

# %%
ldamodel_nouns_f = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=dictionary,
                                           num_topics=num_topics_opt, 
                                           random_state=random_state,
                                           passes=passes)

ldamodel_nouns_f.save('../topic_modeling/model5_nouns_f.gensim') #saving the model

topics_nouns_f = ldamodel_nouns_f.print_topics(num_words=num_words)
for topic in topics_nouns_f:
    print(topic)

lda_nouns_display_f = gensim_models.prepare(ldamodel_nouns_f, corpus, dictionary, sort_topics=True)
vis = pyLDAvis.display(lda_nouns_display_f)
vis
# Out:
# (0, '0.022*"game" + 0.021*"ubmba" + 0.019*"leadership" + 0.019*"team" + 0.015*"diversity"')
# (1, '0.030*"buffalo" + 0.016*"leader" + 0.012*"nomore" + 0.011*"alumni" + 0.011*"family"')
# (2, '0.019*"spring" + 0.018*"student" + 0.014*"health" + 0.012*"school" + 0.011*"program"')
# (3, '0.039*"student" + 0.032*"program" + 0.026*"school" + 0.021*"education" + 0.020*"today"')
# (4, '0.017*"student" + 0.011*"scholarship" + 0.009*"work" + 0.009*"research" + 0.009*"people"')
# (5, '0.032*"year" + 0.022*"happy" + 0.017*"book" + 0.014*"care" + 0.013*"child"')
# (6, '0.023*"thank" + 0.018*"deadline" + 0.016*"emba" + 0.015*"research" + 0.013*"force"')
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el9627140190209909136892943144"></div>
# <script type="text/javascript">
#
# var ldavis_el9627140190209909136892943144_data = {"mdsDat": {"x": [-0.25056215687453637, 0.10445488891770485, 0.20169735682405332, -0.08424039264924188, -0.051221629899913926, -0.013084742211930593, 0.09295667589386428], "y": [-0.14912692114378903, -0.12259586594622747, -0.10190632232897741, 0.024398796106316525, 0.21052336140266015, 0.03829270648667886, 0.10041424542333817], "topics": [1, 2, 3, 4, 5, 6, 7], "cluster": [1, 1, 1, 1, 1, 1, 1], "Freq": [20.02104070235924, 16.183559290962855, 15.6300286556583, 12.955627658660987, 12.939138713258092, 12.244554031887224, 10.026050947213303]}, "tinfo": {"Term": ["buffalo", "thank", "education", "program", "ubmba", "year", "school", "game", "spring", "happy", "leadership", "student", "deadline", "leader", "belovedcommunity", "admission", "pmba", "emba", "gradschool", "book", "question", "diversity", "bull", "congratulations", "application", "register", "session", "team", "health", "research", "admission", "gradschool", "question", "session", "application", "teacher", "symposium", "graduate", "teaching", "black", "conversation", "beginning", "virtual", "literacy", "process", "match", "learning", "noon", "infosession", "instagram", "requirement", "recruitment", "classroom", "july", "schedule", "ambassador", "racial", "nerds", "horn", "curriculum", "history", "education", "october", "experience", "pmba", "belovedcommunity", "register", "program", "morning", "school", "student", "professional", "gift", "information", "today", "event", "center", "panel", "management", "community", "faculty", "career", "tomorrow", "research", "golf", "ceremony", "ball", "outing", "generation", "meeting", "mind", "williams", "kent", "bullying", "sign", "halloween", "start", "stadium", "toledo", "executive", "golfwithubsomaa", "room", "fellowship", "employee", "wish", "amanda", "bowling", "hanukkah", "rachel", "welcome", "green", "offer", "plan", "order", "arena", "manager", "coach", "alumni", "leader", "breakthesilence", "fighter", "state", "buffalo", "nomore", "head", "university", "family", "york", "tplf", "career", "management", "award", "class", "alumnus", "bulls", "business", "civilian", "today", "year", "force", "ethiopia", "school", "congratulation", "grad", "student", "congratulations", "inclusion", "equity", "season", "crime", "summer", "accounting", "blog", "lead", "winter", "post", "miami", "founder", "play", "advice", "easter", "vaccine", "problem", "rebound", "comment", "tesluk", "percent", "cleveland", "championship", "govt", "solution", "victor", "november", "terror", "super", "diversity", "bull", "food", "ubmba", "luck", "game", "leadership", "team", "basketball", "congratulation", "bulls", "justice", "tigray", "point", "story", "home", "dean", "buffalo", "president", "challenge", "opportunity", "today", "support", "alumnus", "spring", "motivationalmonday", "news", "counseling", "poundtherock", "goal", "semester", "facebook", "country", "chance", "tuesday", "click", "dollar", "strategy", "watch", "rsvp", "donor", "king", "picture", "public", "september", "campaign", "dissertation", "martin", "scholarships", "connection", "quotestoliveby", "shirt", "presentation", "report", "conflict", "health", "thing", "all41", "blue", "friend", "white", "night", "boldlybuffalo", "community", "student", "school", "campus", "program", "professor", "world", "woman", "year", "today", "week", "game", "alumnus", "thank", "emba", "tigraygenocide", "westerntigray", "startup", "kindly", "universityatbuffalosuny", "entrepreneur", "knowledge", "journey", "kwanzaa", "supply", "datum", "michigan", "color", "chain", "training", "rebecca", "biden", "crisis", "rest", "susan", "msred", "card", "author", "cinco", "cincodemayo", "mayo", "diwali", "century", "abuse", "deadline", "hand", "congrats", "force", "discussion", "stem", "month", "impact", "research", "business", "entrepreneurship", "space", "quality", "role", "today", "series", "link", "leadership", "week", "student", "happy", "work", "people", "success", "resource",  ...

# %% [markdown]
# #### Save the visualisation

# %%
pyLDAvis.save_html(lda_nouns_display_f, '../topic_modeling/twitter_topic_modeling.html')
